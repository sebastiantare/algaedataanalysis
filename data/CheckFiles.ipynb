# %% [markdown]
# Data from 2022 study

# %% [markdown]
# Vazquez Calderon, F., Araujo, R., Sanchez Lopez, J., Guillen Garcia, J. Algae producing industry. European Commission, Joint Research Centre (JRC) [Dataset] PID:https://data.jrc.ec.europa.eu/dataset/fa59f544-bf77-4812-8869-f34d9b096638

# %%
import pandas as pd
import numpy as np
df = pd.read_excel("./ALGAE-industry_2022_DB_Prod_plants.xlsx", sheet_name='Prod_plants')
print(df.shape)
df.head()
# Out:
# (471, 9)
#    Country    ID Org_group_I Org_group_II  \
# 0  Austria  AT01  Microalgae          NaN
# 1  Austria  AT02  Microalgae    Spirulina
# 2  Austria  AT02   Spirulina   Microalgae
# 3  Austria  AT03   Spirulina          NaN
# 4  Belgium  BE01  Microalgae          NaN
#
#                                  Step in value chain Production method  \
# 0                                Producer, Processor  Photobioreactors
# 1                                Producer, Processor  Photobioreactors
# 2                                Producer, Processor  Photobioreactors
# 3  Producer, Processor, Technology provider, R&D,...        Open ponds
# 4           Producer, Processor, Technology provider  Photobioreactors
#
#   Detail on production system Macroalgae species produced  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#                          Microalgae species produced
# 0                            Haematococcus pluvialis
# 1                                  Chlorella (Genus)
# 2                                  Chlorella (Genus)
# 3                                                NaN
# 4  Chaetoceros muelleri, Diacronema lutheri, Nann...

# %% [markdown]
# ## What useful insights I can obtain from this dataset
# - Buyer Perspective
#     - What are the top producers (countries)
#         - Number of producers (enterprises)
#         - Number of unique products
#         - Number of production methods
#     - Most produced categories
#         - Macroalgae
#         - Microalgae
#         - Spirulina
#     - Most produced species for each category
#     - Most popular production method
# - Seller Perspective
#     - What are the top processors (countries)
#         - Number of processors (enterprises)
#     - Most processed categories
#         - Macroalgae
#         - Microalgae
#         - Spirulina

# %%
# Reshape data.
# Org_group_II into another Org_group_I row.
# If Org_group_I == 'Spirulina', remove data from Macroalgae & Microalgae species produced
# Do the same with org group macroalgae -> remove microalgae species produces, and vice versa
# Encode step in value chain to columns: 0, 1
# Merge species produces into one column
# ?? add cyanobacteria spirulina as species produced

# %%
df.columns
# Out:
# Index(['Country', 'ID', 'Org_group_I', 'Org_group_II', 'Step in value chain',
#        'Production method', 'Detail on production system',
#        'Macroalgae species produced', 'Microalgae species produced'],
#       dtype='object')

# %%
df.head()
# Out:
#    Country    ID Org_group_I Org_group_II  \
# 0  Austria  AT01  Microalgae          NaN
# 1  Austria  AT02  Microalgae    Spirulina
# 2  Austria  AT02   Spirulina   Microalgae
# 3  Austria  AT03   Spirulina          NaN
# 4  Belgium  BE01  Microalgae          NaN
#
#                                  Step in value chain Production method  \
# 0                                Producer, Processor  Photobioreactors
# 1                                Producer, Processor  Photobioreactors
# 2                                Producer, Processor  Photobioreactors
# 3  Producer, Processor, Technology provider, R&D,...        Open ponds
# 4           Producer, Processor, Technology provider  Photobioreactors
#
#   Detail on production system Macroalgae species produced  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#                          Microalgae species produced
# 0                            Haematococcus pluvialis
# 1                                  Chlorella (Genus)
# 2                                  Chlorella (Genus)
# 3                                                NaN
# 4  Chaetoceros muelleri, Diacronema lutheri, Nann...

# %%
columns_to_melt = [
    'Org_group_I', 'Org_group_II'
]

# %%
df_org = pd.melt(df[df['Org_group_II'].isnull() == False], id_vars=['Country', 'ID', 'Step in value chain', 'Production method', 'Detail on production system', 'Macroalgae species produced', 'Microalgae species produced'], value_vars=columns_to_melt,  value_name='Org_group')
df_long = df_org.drop(columns='variable')
print(df_org.shape)
df_org.head()
# Out:
# (164, 9)
#           Country    ID                       Step in value chain  \
# 0         Austria  AT02                       Producer, Processor
# 1         Austria  AT02                       Producer, Processor
# 2  Czech Republic  CZ01  Producer, Processor, Technology provider
# 3  Czech Republic  CZ01  Producer, Processor, Technology provider
# 4         Estonia  EE02  Producer, Processor, Technology provider
#
#                  Production method Detail on production system  \
# 0                 Photobioreactors                         NaN
# 1                 Photobioreactors                         NaN
# 2  Photobioreactors and Fermenters                         NaN
# 3  Photobioreactors and Fermenters                         NaN
# 4                 Photobioreactors                         NaN
#
#   Macroalgae species produced  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                          Microalgae species produced     variable   Org_group
# 0                                  Chlorella (Genus)  Org_group_I  Microalgae
# 1                                  Chlorella (Genus)  Org_group_I   Spirulina
# 2                                  Chlorella (Genus)  Org_group_I  Microalgae
# 3                                                NaN  Org_group_I   Spirulina
# 4  Chlorella (Genus), Dunaliella (Genus), Haemato...  Org_group_I  Microalgae

# %%
df_long
# Out:
#      Country    ID                                Step in value chain  \
# 0    Austria  AT01                                Producer, Processor
# 1    Austria  AT02                                Producer, Processor
# 2    Austria  AT02                                Producer, Processor
# 3    Austria  AT03  Producer, Processor, Technology provider, R&D,...
# 4    Belgium  BE01           Producer, Processor, Technology provider
# ..       ...   ...                                                ...
# 937       UK  UK15                                Producer, Processor
# 938       UK  UK16                                Producer, Processor
# 939       UK  UK17                                Producer, Processor
# 940       UK  UK18                                Producer, Processor
# 941       UK  UK19                                Producer, Processor
#
#        Production method Detail on production system  \
# 0       Photobioreactors                         NaN
# 1       Photobioreactors                         NaN
# 2       Photobioreactors                         NaN
# 3             Open ponds                         NaN
# 4       Photobioreactors                         NaN
# ..                   ...                         ...
# 937  Harvesting - Manual                         NaN
# 938  Harvesting - Manual                         NaN
# 939  Harvesting - Manual                         NaN
# 940     Harvesting - n/a                         NaN
# 941                  NaN                         NaN
#
#     Macroalgae species produced  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 937                     Unknown
# 938                     Unknown
# 939                     Unknown
# 940                     Unknown
# 941                         NaN
#
#                            Microalgae species produced      variable  \
# 0                              Haematococcus pluvialis   Org_group_I
# 1                                    Chlorella (Genus)   Org_group_I
# 2                                    Chlorella (Genus)   Org_group_I
# 3                                                  NaN   Org_group_I
# 4    Chaetoceros muelleri, Diacronema lutheri, Nann...   Org_group_I
# ..                                                 ...           ...
# 937                                                NaN  Org_group_II
# 938                                                NaN  Org_group_II
# 939                                                NaN  Org_group_II
# 940                                                NaN  Org_group_II
# 941                                                NaN  Org_group_II
#
#       Org_group
# 0    Microalgae
# 1    Microalgae
# 2     Spirulina
# 3     Spirulina
# 4    Microalgae
# ..          ...
# 937         NaN
# 938         NaN
# 939         NaN
# 940         NaN
# 941         NaN
#
# [942 rows x 9 columns]

# %%
df_long[df_long['ID'] == 'ES33']
# Out:
#     Country    ID Step in value chain  Production method  \
# 68    Spain  ES33            Producer  Aquaculture - n/a
# 69    Spain  ES33            Producer                NaN
# 150   Spain  ES33            Producer  Aquaculture - n/a
# 151   Spain  ES33            Producer                NaN
#
#     Detail on production system  \
# 68                          NaN
# 69                          NaN
# 150                         NaN
# 151                         NaN
#
#                          Macroalgae species produced  \
# 68   Gracilariopsis longissima, Saccharina latissima
# 69                                               NaN
# 150  Gracilariopsis longissima, Saccharina latissima
# 151                                              NaN
#
#     Microalgae species produced   Org_group
# 68                          NaN  Macroalgae
# 69                      Unknown  Microalgae
# 150                         NaN  Microalgae
# 151                     Unknown  Macroalgae

# %%
df[df['ID'] == 'ES33']
# Out:
#     Country    ID Org_group_I Org_group_II Step in value chain  \
# 407   Spain  ES33  Macroalgae   Microalgae            Producer
# 408   Spain  ES33  Microalgae   Macroalgae            Producer
#
#      Production method Detail on production system  \
# 407  Aquaculture - n/a                         NaN
# 408                NaN                         NaN
#
#                          Macroalgae species produced  \
# 407  Gracilariopsis longissima, Saccharina latissima
# 408                                              NaN
#
#     Microalgae species produced
# 407                         NaN
# 408                     Unknown

# %%
new_rows = []
for index, row in df_long.iterrows():
    categories = row['Step in value chain'].split(', ')
    for category in categories:
        new_row = row.copy()
        new_row['Step in value chain'] = category
        new_rows.append(new_row)

new_df = pd.DataFrame(new_rows)
new_df.head()
# Out:
#           Country    ID Step in value chain                Production method  \
# 0         Austria  AT02            Producer                 Photobioreactors
# 0         Austria  AT02           Processor                 Photobioreactors
# 1         Austria  AT02            Producer                 Photobioreactors
# 1         Austria  AT02           Processor                 Photobioreactors
# 2  Czech Republic  CZ01            Producer  Photobioreactors and Fermenters
#
#   Detail on production system Macroalgae species produced  \
# 0                         NaN                         NaN
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
#
#   Microalgae species produced   Org_group
# 0           Chlorella (Genus)  Microalgae
# 0           Chlorella (Genus)  Microalgae
# 1           Chlorella (Genus)   Spirulina
# 1           Chlorella (Genus)   Spirulina
# 2           Chlorella (Genus)  Microalgae
